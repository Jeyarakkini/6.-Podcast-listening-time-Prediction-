# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
raw_df=pd.read_csv("Podcast_data.csv")
raw_df
# Out:
#             id      Podcast_Name Episode_Title  Episode_Length_minutes  \
# 0            0   Mystery Matters    Episode 98                     NaN
# 1            1     Joke Junction    Episode 26                  119.80
# 2            2    Study Sessions    Episode 16                   73.90
# 3            3    Digital Digest    Episode 45                   67.17
# 4            4       Mind & Body    Episode 86                  110.51
# ...        ...               ...           ...                     ...
# 749995  749995      Learning Lab    Episode 25                   75.66
# 749996  749996   Business Briefs    Episode 21                   75.75
# 749997  749997  Lifestyle Lounge    Episode 51                   30.98
# 749998  749998       Style Guide    Episode 47                  108.98
# 749999  749999    Sports Central    Episode 99                   24.10
#
#              Genre  Host_Popularity_percentage Publication_Day  \
# ...

# %%
raw_df.isnull().sum()
# Out:
# id                                  0
# Podcast_Name                        0
# Episode_Title                       0
# Episode_Length_minutes          87093
# Genre                               0
# Host_Popularity_percentage          0
# Publication_Day                     0
# Publication_Time                    0
# Guest_Popularity_percentage    146030
# Number_of_Ads                       1
# Episode_Sentiment                   0
# Listening_Time_minutes              0
# dtype: int64

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750000 entries, 0 to 749999
# Data columns (total 12 columns):
# id                             750000 non-null int64
# Podcast_Name                   750000 non-null object
# Episode_Title                  750000 non-null object
# Episode_Length_minutes         662907 non-null float64
# Genre                          750000 non-null object
# Host_Popularity_percentage     750000 non-null float64
# Publication_Day                750000 non-null object
# Publication_Time               750000 non-null object
# Guest_Popularity_percentage    603970 non-null float64
# Number_of_Ads                  749999 non-null float64
# Episode_Sentiment              750000 non-null object
# Listening_Time_minutes         750000 non-null float64
# dtypes: float64(5), int64(1), object(6)
# memory usage: 68.7+ MB

# %%
raw_df.describe()
# Out:
#                   id  Episode_Length_minutes  Host_Popularity_percentage  \
# count  750000.000000           662907.000000               750000.000000
# mean   374999.500000               64.504738                   59.859901
# std    216506.495284               32.969603                   22.873098
# min         0.000000                0.000000                    1.300000
# 25%    187499.750000               35.730000                   39.410000
# 50%    374999.500000               63.840000                   60.050000
# 75%    562499.250000               94.070000                   79.530000
# max    749999.000000              325.240000                  119.460000
#
#        Guest_Popularity_percentage  Number_of_Ads  Listening_Time_minutes
# count                603970.000000  749999.000000           750000.000000
# mean                     52.236449       1.348855               45.437406
# std                      28.451241       1.151130               27.138306
# ...

# %%
raw_df.dropna(inplace=True)

# %%
raw_df.isna().sum()
# Out:
# id                             0
# Podcast_Name                   0
# Episode_Title                  0
# Episode_Length_minutes         0
# Genre                          0
# Host_Popularity_percentage     0
# Publication_Day                0
# Publication_Time               0
# Guest_Popularity_percentage    0
# Number_of_Ads                  0
# Episode_Sentiment              0
# Listening_Time_minutes         0
# dtype: int64

# %%
raw_df.describe()
# Out:
#                   id  Episode_Length_minutes  Host_Popularity_percentage  \
# count  539048.000000           539048.000000               539048.000000
# mean   375144.243800               64.556952                   59.728964
# std    216466.180115               32.891153                   22.844111
# min         1.000000                1.240000                    1.300000
# 25%    187832.500000               35.950000                   39.360000
# 50%    375374.000000               63.670000                   59.750000
# 75%    562594.250000               94.020000                   79.370000
# max    749999.000000              325.240000                  119.460000
#
#        Guest_Popularity_percentage  Number_of_Ads  Listening_Time_minutes
# count                539048.000000  539048.000000           539048.000000
# mean                     52.234021       1.324945               45.811258
# std                      28.510395       1.155997               27.231153
# ...

# %%
raw_df.drop(["id"],axis=1,inplace=True)

# %%
raw_df.head()
# Out:
#      Podcast_Name Episode_Title  Episode_Length_minutes       Genre  \
# 1   Joke Junction    Episode 26                  119.80      Comedy
# 2  Study Sessions    Episode 16                   73.90   Education
# 3  Digital Digest    Episode 45                   67.17  Technology
# 4     Mind & Body    Episode 86                  110.51      Health
# 6  Criminal Minds    Episode 47                   69.83  True Crime
#
#    Host_Popularity_percentage Publication_Day Publication_Time  \
# 1                       66.95        Saturday        Afternoon
# 2                       69.97         Tuesday          Evening
# 3                       57.22          Monday          Morning
# 4                       80.07          Monday        Afternoon
# 6                       35.82          Sunday            Night
#
#    Guest_Popularity_percentage  Number_of_Ads Episode_Sentiment  \
# 1                        75.95            2.0          Negative
# ...

# %%
raw_df["Listening_Time_minutes"].value_counts().sort_index()
# Out:
# 0.00000      4967
# 0.00056         2
# 0.00175         7
# 0.00661        13
# 0.01050         5
#              ...
# 119.78000      10
# 119.79000       8
# 119.80000      14
# 119.90000      11
# 119.97000      19
# Name: Listening_Time_minutes, Length: 42733, dtype: int64

# %%
pd.set_option("max_rows",None)

# %%
from Univariate import Univariate

# %%
quan,qual=Univariate.quanQual(raw_df)

# %%
quan
# Out:
# ['Episode_Length_minutes',
#  'Host_Popularity_percentage',
#  'Guest_Popularity_percentage',
#  'Number_of_Ads',
#  'Listening_Time_minutes']

# %%
descriptive=Univariate.descriptive(raw_df,quan)
descriptive
# Out:
#              Episode_Length_minutes Host_Popularity_percentage  \
# Max                          325.24                     119.46
# Min                            1.24                        1.3
# Mean                         64.557                     59.729
# Median                        63.67                      59.75
# Mode                           34.4                      38.68
# Q1:25%                        35.95                      39.36
# Q2:50%                        63.67                      59.75
# Q3:75%                        94.02                      79.37
# Q4:100%                      325.24                     119.46
# IQR                           58.07                      40.01
# 1.5IQR                       87.105                     60.015
# lesserRange                 -51.155                    -20.655
# greaterRange                181.125                    139.385
#
#              Guest_Popularity_percentage Number_of_Ads Listening_Time_minutes
# ...

# %%
lesser,greater=Univariate.findOutlier(descriptive,quan)

# %%
lesser
# Out:
# []

# %%
greater
# Out:
# ['Episode_Length_minutes', 'Number_of_Ads']

# %%
replaced_df=Univariate.replaceOutlier(raw_df,descriptive,lesser,greater,quan)
# Out:
# D:\HopeAI\9.Capstone Project - DS & ML\Univariate.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[columnName][dataset[columnName]>descriptive[columnName]['greaterRange']]=descriptive[columnName]['greaterRange']

# %%
quan,qual=Univariate.quanQual(replaced_df)
descriptive=Univariate.descriptive(replaced_df,quan)
descriptive
# Out:
#              Episode_Length_minutes Host_Popularity_percentage  \
# Max                         181.125                     119.46
# Min                            1.24                        1.3
# Mean                        64.5567                     59.729
# Median                        63.67                      59.75
# Mode                           34.4                      38.68
# Q1:25%                        35.95                      39.36
# Q2:50%                        63.67                      59.75
# Q3:75%                        94.02                      79.37
# Q4:100%                     181.125                     119.46
# IQR                           58.07                      40.01
# 1.5IQR                       87.105                     60.015
# lesserRange                 -51.155                    -20.655
# greaterRange                181.125                    139.385
#
#              Guest_Popularity_percentage Number_of_Ads Listening_Time_minutes
# ...

# %%
lesser,greater=Univariate.findOutlier(descriptive,quan)

# %%
greater
# Out:
# []

# %%
replaced_df.to_csv('Preprocessed_Podcast_data.csv', index=False)
